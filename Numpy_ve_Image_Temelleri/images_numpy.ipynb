# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic =Image.open(r"C:\Users\umuty\Desktop\Python ile Goruntu Isleme\Python-ile-goruntu-isleme\Numpy ve Image Temelleri\media\manzara.jpeg")

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6C76-DED2
#
#  Directory of c:\Users\umuty\Desktop\Python ile goruntu isleme\Python-ile-goruntu-isleme\Numpy ve Image Temelleri
#
# 22.10.2024  23:32    <DIR>          .
# 22.10.2024  22:47    <DIR>          ..
# 22.10.2024  23:29                 0 images_numpy.ipynb
# 22.10.2024  23:33    <DIR>          media
# 22.10.2024  23:13             1.700 numpy_arrays.ipynb
#                2 File(s)          1.700 bytes
#                3 Dir(s)  483.861.364.736 bytes free

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_array= np.asarray(pic)

# %%
type(pic_array)
# Out:
# numpy.ndarray

# %%
pic_array.shape
# Out:
# (168, 300, 3)

# %%
plt.imshow(pic)

# %%
pic_copy=pic_array.copy()

# %%
pic_copy[:,:,0] #kırmızı rengin oldugu bolge
# Out:
# array([[244, 227, 217, ...,  56,  56,  56],
#        [255, 245, 235, ...,  57,  57,  57],
#        [255, 249, 242, ...,  59,  58,  58],
#        ...,
#        [179, 181, 181, ...,  31,  32,  32],
#        [177, 175, 166, ...,  28,  28,  29],
#        [199, 191, 174, ...,  27,  27,  28]], dtype=uint8)

# %%
plt.imshow(pic_copy[:,:,0])

# %%
plt.imshow(pic_copy[:,:,0],cmap="gray")  #kırmızının oldugu alanda beyaz ton daha cok gozukur

# %%
plt.imshow(pic_copy[:,:,1],cmap="gray")  #yesilin oldugu alanda beyaz ton daha cok gozukur

# %%
plt.imshow(pic_copy[:,:,2],cmap="gray")  #mavinin oldugu alanda beyaz ton daha cok gozukur

# %%
pic_copy[:,:,1]=0   #mavi ve yesil olan kanallara 0 verdik
pic_copy[:,:,2]=0

# %%
plt.imshow(pic_copy) #elimizde sadece kırmızı kanalın oldugu fotograf kaldı
