# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import cv2

# %%
path = os.path.join(os.getcwd(), "media", "manzara.jpeg")



img = cv2.imread(path)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[ 79, 164, 244],
#         [ 62, 147, 227],
#         [ 50, 137, 217],
#         ...,
#         [ 83,  70,  56],
#         [ 83,  70,  56],
#         [ 83,  70,  56]],
#
#        [[ 95, 180, 255],
#         [ 80, 165, 245],
#         [ 68, 155, 235],
#         ...,
#         [ 84,  71,  57],
#         [ 84,  71,  57],
#         [ 84,  71,  57]],
#
#        [[ 93, 177, 255],
#         [ 83, 167, 249],
#         [ 74, 160, 242],
#         ...,
#         [ 83,  71,  59],
#         [ 85,  72,  58],
#         [ 85,  72,  58]],
#
#        ...,
#
#        [[ 29, 113, 179],
#         [ 35, 114, 181],
#         [ 42, 111, 181],
#         ...,
#         [ 44,  50,  31],
#         [ 45,  51,  32],
#         [ 45,  51,  32]],
#
#        [[ 35, 116, 177],
#         [ 36, 113, 175],
#         [ 33, 101, 166],
#         ...,
#         [ 44,  49,  28],
#         [ 44,  49,  28],
#         [ 45,  50,  29]],
#
#        [[ 61, 142, 199],
#         [ 57, 134, 191],
#         [ 44, 111, 174],
# ...

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
plt.imshow(img)  #renkler farkli cikar cunku matplotlib fonksiyonu RGB renk uzayini kullanir
#ama opencv BGR renk uzayini kullanir

# %%
fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
gray= cv2.imread(path, cv2.IMREAD_GRAYSCALE) #resmi gri tonlarda alir

# %%
gray.shape
# Out:
# (168, 300)

# %%
gray
# Out:
# array([[178, 161, 151, ...,  67,  67,  67],
#        [194, 179, 169, ...,  68,  68,  68],
#        [192, 182, 175, ...,  69,  69,  69],
#        ...,
#        [123, 125, 124, ...,  44,  45,  45],
#        [125, 123, 113, ...,  42,  42,  43],
#        [150, 142, 122, ...,  41,  41,  42]], dtype=uint8)

# %%
gray.min()
# Out:
# 0

# %%
gray.max()
# Out:
# 255

# %%
plt.imshow(gray)

# %%
plt.imshow(gray, cmap='gray') #fotografimizin gri tonlada oldugunu soyluyoruz

# %%
plt.imshow(gray, cmap='magma') #fotografimizi magma renk uzayinda gosteriyoruz

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (168, 300, 3)

# %%
new_resize=cv2.resize(fix_img,(600,420))

# %%
plt.imshow(new_resize)

# %%
w_ratio=0.5  #asil fotografimizin yarisini almak istiyoruz
h_ratio=0.5

# %%
new_img=cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (84, 150, 3)

# %%
new_img = cv2.flip(fix_img,0) #0 x eksenine gore, 1 y eksenine gore

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img,-1) #hem x eksenine hem de y eksenine gore ters cevirir

# %%
plt.imshow(new_img)
